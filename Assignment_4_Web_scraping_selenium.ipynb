# %%
#Import required Libraries
import selenium
import pandas as pd
import time
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import StaleElementReferenceException
import warnings
warnings.filterwarnings('ignore')

# %% [raw]
# Q.1. Scrape the details of most viewed videos on YouTube from Wikipedia:
# Url= https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
#  You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
driver = webdriver.Chrome(r"C:\Users\rahsh\Downloads\driver\chromedriver.exe")

# %%
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
# Let's create an empty lists to store the scraping data
Rank=[]
Name=[]
Artist=[]
Views=[]
Upload_Date=[]

#Let's create a function to get the details of most viewed video on youtube
rank = driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[1]')
for i in rank:
    Rank.append(i.text)
name = driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[2]')
for i in name:
    Name.append(i.text)
artist = driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[3]')
for i in artist:
    Artist.append(i.text)
view = driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[4]')
for i in view:
    Views.append(i.text)
date = driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[5]')
for i in date:
    Upload_Date.append(i.text)

# %%
# Let's create the dataframe from the scraped data
videos=pd.DataFrame({})
videos['Rank']=Rank[0:30]
videos['Name']=Name[0:30]
videos['Artist']=Artist[0:30]
videos['Upload Date']=Upload_Date[0:30]
videos['Views (Billions)']=Views[0:30]
videos
# Out:
#    Rank                                       Video Name  \
# 0    1.                           "Baby Shark Dance"[22]
# 1    2.                                  "Despacito"[24]
# 2    3.                               "Shape of You"[25]
# 3    4.                       "Johny Johny Yes Papa"[26]
# 4    5.                              "See You Again"[27]
# 5    6.   "Masha and the Bear – Recipe for Disaster"[30]
# 6    7.                                "Uptown Funk"[31]
# 7    8.                              "Gangnam Style"[32]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[34]
# 9   10.                                  "Bath Song"[35]
# 10  11.                "Phonics Song with Two Words"[36]
# 11  12.                                      "Sugar"[37]
# 12  13.                                      "Sorry"[38]
# 13  14.                                       "Roar"[39]
# 14  15.                             "Dame Tu Cosita"[40]
# ...

# %%
import selenium
import pandas as pd
import time
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import StaleElementReferenceException
import warnings
warnings.filterwarnings('ignore')

# %% [raw]
# Q.2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
driver = webdriver.Chrome(r"C:\Users\rahsh\Downloads\driver\chromedriver.exe")

# %%
driver.get("https://www.bcci.tv/")

# %%
international = driver.find_element_by_xpath("//div[@class = 'navigation__drop-down drop-down drop-down--reveal-on-hover']")
international.click()

# %%
fixtures = driver.find_element_by_xpath("//a[@href = '/international/fixtures']")
fixtures.click()

# %%
#create an empty list to store scraped data
Title=[] 
Series=[]
Place=[] 
Date=[] 
Time=[]

#Now fetching the data 
title = driver.find_elements_by_xpath('//strong[@class="fixture__name fixture__name--with-margin"]')
for x in title:
    Title.append(x.text)
series = driver.find_elements_by_xpath('//div[@class="fixture__format-strip"]/span[2]')
for x in series:
    Series.append(x.text)
place = driver.find_elements_by_xpath('//p[@class="fixture__additional-info"]/span')
for x in place:
    Place.append(x.text)
date = driver.find_elements_by_xpath('//div[@class="fixture__datetime desktop-only"]/div/span')
month = driver.find_elements_by_xpath('//div[@class="fixture__datetime desktop-only"]/div/div/span[1]')
for x in range(len(date)):
    Date.append(date[x].text + month[x].text)
time = driver.find_elements_by_xpath('//div[@class="fixture__full-date"]/div/span[2]')
for x in time:
    Time.append(x.text)
    
# NOW create the dataframe for scraped data
INT_FIX=pd.DataFrame({})
INT_FIX['Match Title']=Title
INT_FIX['Series']=Series
INT_FIX['Place']=Place 
INT_FIX['Date']=Date
INT_FIX['Time']=Time
INT_FIX
# Out:
#   Match Title                             Series                        Place  \
# 0       Final  ICC WORLD TEST CHAMPIONSHIP FINAL  The Ageas Bowl, Southampton
# 1    1st Test               ENGLAND V INDIA 2021     Trent Bridge, Nottingham
# 2    2nd Test               ENGLAND V INDIA 2021               Lord's, London
# 3    3rd Test               ENGLAND V INDIA 2021            Headingley, Leeds
# 4    4th Test               ENGLAND V INDIA 2021             The Oval, London
# 5    5th Test               ENGLAND V INDIA 2021     Old Trafford, Manchester
#
#           Date       Time
# 0       18JUNE  15:30 IST
# 1     04AUGUST  15:30 IST
# 2     12AUGUST  15:30 IST
# 3     25AUGUST  15:30 IST
# 4  02SEPTEMBER  15:30 IST
# 5  10SEPTEMBER  15:30 IST

# %% [raw]
# Q.3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
import selenium
import pandas as pd
import time
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import StaleElementReferenceException
import warnings
warnings.filterwarnings('ignore')

# %%
driver = webdriver.Chrome(r"C:\Users\rahsh\Downloads\driver\chromedriver.exe")

# %%
driver.get("https://www.guru99.com/")

# %%
selenium_tutorial = driver.find_element_by_xpath("//ul[@class = 'menu']/li[3]/a")
selenium_tutorial.click()

# %%
sel_handling = driver.find_element_by_xpath("//table[@class='table']/tbody/tr[34]/td/a")
sel_handling.click()

# %%
Name=[]
Description=[]

# %%
name = driver.find_elements_by_xpath('//table[@class="table table-striped"]/tbody/tr/td[1]')
for i in name:
    Name.append(i.text)
describe = driver.find_elements_by_xpath('//table[@class="table table-striped"]/tbody/tr/td[2]')
for i in describe:
    Description.append(i.text)

# %%
SEH=pd.DataFrame({})
SEH['Exception Name']=Name[1:]
SEH['Description']=Description[1:]
SEH
# Out:
#                          Exception Name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %% [raw]
# Q.4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP(18-19)
# D) GSDP(17-18)
# E) Share(2017)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
import selenium
import pandas as pd
import time
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import StaleElementReferenceException
import warnings
warnings.filterwarnings('ignore')

# %%
driver = webdriver.Chrome(r"C:\Users\rahsh\Downloads\driver\chromedriver.exe")

# %%
driver.get("http://statisticstimes.com/")

# %%
economy = driver.find_element_by_xpath("//div[@id='top']/div[2]/div[2]/button/i").click()

# %%
india = driver.find_element_by_xpath("//a[@href= 'economy/india-statistics.php']").click()

# %%
stategdp = driver.find_element_by_xpath("//a[@href= 'india/indian-states-gdp.php']").click()

# %%
Rank = []
State = []
GSDP1 = []
GSDP2 = []
Share = []
GDP = []

# %%
rank = driver.find_elements_by_xpath("//table[@id= 'table_id']/tbody/tr/td[1]")
for i in rank:
    Rank.append(i.text)
state = driver.find_elements_by_xpath("//table[@id= 'table_id']/tbody/tr/td[2]")
for i in state:
    State.append(i.text)
gsdp1 = driver.find_elements_by_xpath("//table[@id= 'table_id']/tbody/tr/td[3]")
for i in gsdp1:
    GSDP1.append(i.text)
gsdp2 = driver.find_elements_by_xpath("//table[@id= 'table_id']/tbody/tr/td[4]")
for i in gsdp2:
    GSDP2.append(i.text)
share = driver.find_elements_by_xpath("//table[@id= 'table_id']/tbody/tr/td[5]")
for i in share:
    Share.append(i.text)
gdp = driver.find_elements_by_xpath("//table[@id= 'table_id']/tbody/tr/td[6]")
for i in gdp:
    GDP.append(i.text)

# %%
import pandas as pd
GDP_INDIA = pd.DataFrame({})
GDP_INDIA["Rank"] = Rank
GDP_INDIA["State"] = State
GDP_INDIA["GSDP_19-20"] = GSDP1
GDP_INDIA["GSDP_18-19"] = GSDP2
GDP_INDIA["Share"] = Share
GDP_INDIA["GDP(billion_dollars)"] = GDP
GDP_INDIA
# Out:
#    Rank                      State GSDP_19-20 GSDP_18-19   Share  \
# 0     1                Maharashtra          -  2,632,792  13.88%
# 1     2                 Tamil Nadu  1,845,853  1,630,208   8.59%
# 2     3              Uttar Pradesh  1,687,818  1,584,764   8.35%
# 3     4                    Gujarat          -  1,502,899   7.92%
# 4     5                  Karnataka  1,631,977  1,493,127   7.87%
# 5     6                West Bengal  1,253,832  1,089,898   5.75%
# 6     7                  Rajasthan  1,020,989    942,586   4.97%
# 7     8             Andhra Pradesh    972,782    862,957   4.55%
# 8     9                  Telangana    969,604    861,031   4.54%
# 9    10             Madhya Pradesh    906,672    809,592   4.27%
# 10   11                     Kerala          -    781,653   4.12%
# 11   12                      Delhi    856,112    774,870   4.08%
# 12   13                    Haryana    831,610    734,163   3.87%
# ...

# %% [raw]
# Q.5 Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
import selenium
import pandas as pd
import time
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import StaleElementReferenceException
import warnings
warnings.filterwarnings('ignore')

# %%
driver = webdriver.Chrome(r"C:\Users\rahsh\Downloads\driver\chromedriver.exe")

# %%
driver.get("https://github.com/")

# %%
threebar = driver.find_element_by_xpath("//div[@class='d-flex flex-items-center']/button").click()

explore = driver.find_element_by_xpath("//ul[@class= 'd-lg-flex list-style-none']/li[4]").click()

trending = driver.find_element_by_xpath("//a[@href = '/trending']").click()

# Let's create an empty lists to store scraping data
Repository_Title=[]
Repository_Description=[] 
Contributors_Count=[] 
Language_Used=[]
urls=[]

title = driver.find_elements_by_xpath("//article[@class='Box-row']/h1/a")
for i in title:
    Repository_Title.append(i.text)
    urls.append(i.get_attribute('href'))
    
descriptions=driver.find_elements_by_xpath("//article[@class='Box-row']/p")
for i in descriptions:
    Repository_Description.append(i.text)

for url in urls:
    driver.get(url)
    driver.implicitly_wait(3)
    div_list=driver.find_elements_by_xpath('//div[@class="BorderGrid BorderGrid--spacious"]/div')
    try:
        Contributors_Count.append(((div_list[-2].text).split())[1])
    except:
        Contributors_Count.append('---')
    try:
        Language_Used.append(((div_list[-1].text).split())[1::2])
    except:
        Language_Used.append('---')
        
        
print(len(Repository_Title),len(Repository_Description),len(Contributors_Count),len(Language_Used))
# Out:
# 25 24 25 25

# %%
Repositoriy=pd.DataFrame({})
Repositoriy['Repository Title']=Repository_Title[0:24]
Repositoriy['Repository Description']=Repository_Description[0:24]
Repositoriy['Contributors Count']=Contributors_Count[0:24]
Repositoriy['Language Used']=Language_Used[0:24]
Repositoriy
# Out:
#                                      Repository Title  \
# 0                     pallupz / covid-vaccine-booking
# 1                          DIGITALCRIMINAL / OnlyFans
# 2                           public-apis / public-apis
# 3                        alura-cursos / imersaodados3
# 4                                       github / docs
# 5                     jlevy / the-art-of-command-line
# 6                                 dogecoin / dogecoin
# 7                                   thedevdojo / wave
# 8               jwasham / coding-interview-university
# 9                          TheAlgorithms / Javascript
# 10                                 devsuperior / sds3
# 11          terraform-aws-modules / terraform-aws-eks
# 12                                andrejbauer / plzoo
# 13               Shahzod114 / NodeRelax-Blender-Addon
# 14                       ionic-team / ionic-framework
# 15  bhattbhavesh91 / cowin-vaccination-slot-availa...
# ...

# %% [raw]
# Q.6. Scrape the details of top 100 songs on billiboard.com.
# Url = https://www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
import selenium
import pandas as pd
import time
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import StaleElementReferenceException
import warnings
warnings.filterwarnings('ignore')

# %%
driver = webdriver.Chrome(r"C:\Users\rahsh\Downloads\driver\chromedriver.exe")

# %%
driver.get('https://www.billboard.com/')

# %%
# Let's navigate and click on the Top 100 Songs
driver.find_element_by_xpath("//nav[@class='header__subnav bg--light']/ul/li[3]/a").click()

# %%
# Let's create an empty lists to store the scraping data
Song_Name=[]
Artist_Name=[] 
Last_Week_Rank=[] 
Peak_Rank=[]
Weeks_on_Board=[]

# %%
# Let's create a function
song = driver.find_elements_by_xpath('//span[@class="chart-element__information__song text--truncate color--primary"]')
for i in song:
    Song_Name.append(i.text)
artist = driver.find_elements_by_xpath('//span[@class="chart-element__information__artist text--truncate color--secondary"]')
for i in artist:
    Artist_Name.append(i.text)
lastweek = driver.find_elements_by_xpath('//div[@class="chart-element__meta text--center color--secondary text--last"]')
for i in lastweek:
    Last_Week_Rank.append(i.text)
peak = driver.find_elements_by_xpath('//div[@class="chart-element__meta text--center color--secondary text--peak"]')
for i in peak:
    Peak_Rank.append(i.text)
weeks = driver.find_elements_by_xpath('//div[@class="chart-element__meta text--center color--secondary text--week"]')
for i in weeks:
    Weeks_on_Board.append(i.text)

# %%
# Let's create the dataframe from the scraped data
topsongs=pd.DataFrame({})
topsongs['Song_name']=Song_Name
topsongs['Artist_name']=Artist_Name
topsongs['Last_week_rank']=Last_Week_Rank
topsongs['Peak_rank']=Peak_Rank
topsongs['Weeks_on_board']= Weeks_on_Board
topsongs
# Out:
#               Song_name                                     Artist_name  \
# 0       Save Your Tears                      The Weeknd & Ariana Grande
# 1   Leave The Door Open        Silk Sonic (Bruno Mars & Anderson .Paak)
# 2               Peaches  Justin Bieber Featuring Daniel Caesar & Giveon
# 3               Rapstar                                          Polo G
# 4            Levitating                       Dua Lipa Featuring DaBaby
# ..                  ...                                             ...
# 95            4 Da Gang                           42 Dugg & Roddy Ricch
# 96      Blame It On You                                    Jason Aldean
# 97        Wasted On You                                   Morgan Wallen
# 98         Way Less Sad                                             AJR
# 99         Clear Da Air                                    Moneybagg Yo
#
#    Last_week_rank Peak_rank Weeks_on_board
# 0               6         1             20
# ...

# %% [raw]
# Q.7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and then on the search panel type Data science and
# click on search. All this should be done through code.

# %%
driver = webdriver.Chrome(r"C:\Users\rahsh\Downloads\driver\chromedriver.exe")

# %%
driver.get('https://www.naukri.com/')

# %%
recruiter=driver.find_element_by_xpath("//ul[@class='midSec menu']/li[2]/a")
driver.get(recruiter.get_attribute('href'))

# %%
search_panel=driver.find_element_by_xpath("//input[@class='sugInp']")
search_panel.send_keys("Data Science")
search_button=driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']").click()

# %%
Name=[]
Designation=[] 
Company=[] 
Skills_they_hire_for=[] 
Location=[]

# %%
name = driver.find_elements_by_xpath('//span[@class="fl ellipsis"]')
for i in name:
    Name.append(i.text)
designation = driver.find_elements_by_xpath('//span[@class="ellipsis clr"]')
for i in designation:
    Designation.append(i.text)
company = driver.find_elements_by_xpath('//p[@class="highlightable"]/a[2]')
for i in company:
    Company.append(i.text)
skill = driver.find_elements_by_xpath('//div[@class="hireSec highlightable"]')
for i in skill:
    Skills_they_hire_for.append(i.text)
loc = driver.find_elements_by_xpath('//p[@class="highlightable"]/span[2]')
for i in loc:
    try:
        Location.append(i.text)
    except NoSuchElementException:        
        Location.append("NA")

# %%
Naukri=pd.DataFrame({})
Naukri['Name']=Name[0:25]
Naukri['Designation']=Designation[0:25]
Naukri['Company']=Company[0:25]
Naukri['Skills they Hire for']= Skills_they_hire_for[0:25]
Naukri['Location']=Location[0:25]
Naukri
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                    Talent Acquisition Executive
# 3                                    Anik Agrawal
# 4                        MARSIAN Technologies LLP
# 5                                    subhas patel
# 6    Abhishek - Only Analytics Hiring - India and
# 7   Institute for Financial Management and Resear
# 8                                     Balu Ramesh
# 9                                   Asif Lucknowi
# 10                                InstaFinancials
# 11                                Kalpana Dumpala
# 12                                        Mubarak
# 13                                 Kushal Rastogi
# 14                                    Ruchi Dhote
# 15                             Mahesh Babu Channa
# 16                                   Kapil Devang
# 17                                    Priya Khare
# ...

# %% [raw]
# Q.8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
driver = webdriver.Chrome(r"C:\Users\rahsh\Downloads\driver\chromedriver.exe")

# %%
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/')

# %%
Book_Name=[] 
Author_Name=[] 
Volumes_Sold=[]
Publisher=[] 
Genre=[]

# %%
book = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[2]')
for i in book:
    Book_Name.append(i.text)
author = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[3]')
for i in author:
    Author_Name.append(i.text)
vol = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[4]')
for i in vol:
    Volumes_Sold.append(i.text)
pub = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[5]')
for i in pub:
    Publisher.append(i.text)
gen = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[6]')
for i in gen:
    Genre.append(i.text)

# %%
# Let's create the dataframe from the scraped data
Book=pd.DataFrame({})
Book['Book Name']=Book_Name
Book['Author Name']= Author_Name
Book['Volumes Sold']=Volumes_Sold
Book['Publisher']=Publisher
Book['Genre']=Genre
Book
# Out:
#                                             Book Name       Author Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes Sold        Publisher                        Genre
# ...

# %% [raw]
# Q.9. Scrape the details most watched tv series of all time from imdb.com.
#  Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
driver = webdriver.Chrome(r"C:\Users\rahsh\Downloads\driver\chromedriver.exe")

# %%
driver.get('https://www.imdb.com/list/ls095964455/')

# %%
Name=[]
Year_Span=[] 
Genre=[] 
Run_Time=[] 
Ratings=[] 
Votes=[]

# %%
name = driver.find_elements_by_xpath('//h3[@class="lister-item-header"]/a')
for i in name:
    Name.append(i.text)
year = driver.find_elements_by_xpath('//span[@class="lister-item-year text-muted unbold"]')
for i in year:
    Year_Span.append(i.text)
gen = driver.find_elements_by_xpath('//span[@class="genre"]')
for i in gen:
    Genre.append(i.text)
runtime = driver.find_elements_by_xpath('//span[@class="runtime"]')
for i in runtime:
    Run_Time.append(i.text)
ratings = driver.find_elements_by_xpath('//div[@class="ipl-rating-star small"]')
for i in ratings:
    Ratings.append(i.text)
vote = driver.find_elements_by_xpath('//span[@name="nv"]')
for i in vote:
    Votes.append(i.text)

# %%
TV_Series=pd.DataFrame({})
TV_Series['Name']=Name
TV_Series['Year Span']= Year_Span
TV_Series['Genre']=Genre
TV_Series['Run Time']= Run_Time
TV_Series['Ratings']=Ratings
TV_Series['Votes']=Votes
TV_Series
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.3  1,802,840
# ...

# %% [raw]
# Q.10. Details of Datasets from UCI machine learning repositories.
#  Url = https://archive.ics.uci.edu/
#  You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the Show All Dataset page through code.

# %%
driver = webdriver.Chrome(r"C:\Users\rahsh\Downloads\driver\chromedriver.exe")

# %%
driver.get('https://archive.ics.uci.edu/')

# %%
dataset=driver.find_element_by_xpath("//span[@class='normal']/b/a")
driver.get(dataset.get_attribute('href'))

# %%
Dataset_Name=[] 
Data_Type=[]
Task=[] 
Attribute_Type=[] 
No_of_Instances=[] 
No_of_Attribute=[] 
Year=[]

# %%
name = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr[2]/td/table/tbody/tr/td[2]/p/b/a')
for i in name:
    Dataset_Name.append(i.text)
name = driver.find_elements_by_xpath('//tr[@bgcolor="DDEEFF"]/td/table/tbody/tr/td[2]/p/b/a')
for i in name:
    Dataset_Name.append(i.text)
datatype = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr[2]/td[2]/p')
for i in datatype:
    Data_Type.append(i.text)
datatype = driver.find_elements_by_xpath('//tr[@bgcolor="DDEEFF"]/td[2]/p')
for i in datatype:
    Data_Type.append(i.text)
task = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr[2]/td[3]/p')
for i in task:
    Task.append(i.text)
task = driver.find_elements_by_xpath('//tr[@bgcolor="DDEEFF"]/td[3]/p')
for i in task:
    Task.append(i.text)
attribute = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr[2]/td[4]/p')
for i in attribute:
    Attribute_Type.append(i.text)
attribute = driver.find_elements_by_xpath('//tr[@bgcolor="DDEEFF"]/td[4]/p')
for i in attribute:
    Attribute_Type.append(i.text)
instances = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr[2]/td[5]/p')
for i in instances:
    No_of_Instances.append(i.text)
instances = driver.find_elements_by_xpath('//tr[@bgcolor="DDEEFF"]/td[5]/p')
for i in instances:
    No_of_Instances.append(i.text)
numberattribute = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr[2]/td[6]/p')
for i in numberattribute:
    No_of_Attribute.append(i.text)
numberattribute = driver.find_elements_by_xpath('//tr[@bgcolor="DDEEFF"]/td[6]/p')
for i in numberattribute:
    No_of_Attribute.append(i.text)
year = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr[2]/td[7]/p')
for i in year:
    Year.append(i.text)
year = driver.find_elements_by_xpath('//tr[@bgcolor="DDEEFF"]/td[7]/p')
for i in year:
    Year.append(i.text)

# %%
UCI=pd.DataFrame({})
UCI['Dataset Name']=Dataset_Name 
UCI['Data Type']=Data_Type
UCI['Task']=Task
UCI['Attribute Type']=Attribute_Type
UCI['No of Instances']=No_of_Instances
UCI['No of Attribute']= No_of_Attribute
UCI['Year']=Year
UCI
# Out:
#                                  Dataset Name                   Data Type  \
# 0                                     Abalone               Multivariate
# 1                                       Adult               Multivariate
# 2                Anonymous Microsoft Web Data
# 3                       Artificial Characters               Multivariate
# 4                    Audiology (Standardized)               Multivariate
# ..                                        ...                         ...
# 290                LastFM Asia Social Network               Multivariate
# 291  AI4I 2020 Predictive Maintenance Dataset  Multivariate, Time-Series
# 292          in-vehicle coupon recommendation               Multivariate
# 293                 Wikipedia Math Essentials                Time-Series
# 294              Synchronous Machine Data Set               Multivariate
#
#                                               Task  \
# 0                                  Classification
# ...
